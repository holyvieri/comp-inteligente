# %% [markdown]
# # AGO
# ---
# ## Requisitos
# - Geração aleatória
# - Seleção por proporcionalidade do fitness e por torneio
# - Cruzamento por 1 ponto e por 2 pontos - Podendo ajustar a taxa de cruzamento
# - Mutação - Podendo ajustar a taxa de mutação
# - Sphere: 30 dimensões (ou seja 30 variáveis) #parametrização
#         - Os limites de cada variável é de: -100 a 100  #parametrização
# - Tamanho da População = 30
# - Quantidade de gerações = 20
#
# ---

# %% [markdown]
# - Cromossomo: É a estrutura de dados que representa uma solução completa para o problema. No código, cada indivíduo da lista pop será um cromossomo.
# - Gene: É cada elemento individual dentro dessa estrutura (cada valor na lista). Se o problema tem 6 variáveis que precisam ser ajustadas para encontrar o melhor resultado, então o cromossomo terá 6 genes. Ou seja, na Sphere, seriam 6 dimensões
#
# - Sobre os "var_x": são limites, definem o intervalo válido para o valor de cada gene. No caso da Sphere, cada variável (gene) deve estar entre -100 e 100: cromossomo = [45.3, -72.1, 0.5, 88.9, -12.4, ...]

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
# parametros do AG
n_pop = 30
quantidade_genes = 30
n_geracoes = 20
pop = []
nova_pop = []
n_cortes = 2
taxa_crossover = 0.5242
taxa_mutacao = 0.0161
selecao='torneio'

# Random seed
random_seed = 1000

# Parametros da sphere
n_dimensoes = quantidade_genes
var_min = -100
var_max = 100

#elitismo
n_elitismo = 2

# %% [markdown]
# ## Gerar População

# %%
# Configurar seed para reprodutibilidade
random.seed(random_seed)
np.random.seed(random_seed)

pop.clear()
#Loop para criar cada indivíduo da população:
for i in range(n_pop):
    cromossomo = [random.uniform(var_min, var_max) for _ in range(n_dimensoes)]
    pop.append(cromossomo)
    #print(f"cromossomo {i+1} gerado: {cromossomo}")
    #print("\n")

# %%
#pop

# %% [markdown]
# ## Funções

# %%
import math


def sphere(x):
    """
    Sphere Function
    Mínimo global: f(0, ..., 0) = 0
    """
    return sum(xi**2 for xi in x)


def rastrigin(x):
    """
    Rastrigin Function
    Mínimo global: f(0, ..., 0) = 0
    """
    n = len(x)
    return 10*n + sum(xi**2 - 10*math.cos(2 * math.pi * xi) for xi in x)

def rosenbrock(x):
    """
    Rosenbrock Function
    Mínimo global: f(1, ..., 1) = 0
    """
    return sum(100 * (x[i+1] - x[i]**2)**2 + (x[i] - 1)**2 for i in range(len(x)-1))

# %% [markdown]
# ## Avaliar cada individuo

# %%
pop_aval= []
pop_aval.clear()
for cromossomo in pop:
    nota_aval = sphere(cromossomo)
    pop_aval.append((cromossomo, nota_aval))

#pop_aval

# %% [markdown]
# ## Selecionar os individuos mais aptos

# %% [markdown]
# - Pais 1 com ROLETA
# - lembrando: problema de minimização -> quanto menor a avaliação, maior o valor da aptidão.
# - fitness = 1/(1 + nota avaliaçao)
# - pop_aval = [(cromossomo, nota_aval), ...]

# %%
def calcular_fitness(pop_avaliada):
    """
    Recebe: lista de tuplas (cromossomo, valor_sphere)
    Retorna: lista de pesos de fitness
    """
    return [1 / (1 + individuo[1]) for individuo in pop_avaliada]

#def mostrar_probabilidade(pop_avaliada):
#    """
#    Mostra cada cromossomo com sua avaliação e probabilidade relativa
#    """
#    fitness = calcular_fitness(pop_avaliada)
#    total = sum(fitness)
#    probabilidades = [f/total for f in fitness]
#
#    for i, (crom, fitness) in enumerate(pop_avaliada):
#        print(f"Cromossomo {i+1}: avaliação={fitness:.2f}, probabilidade={probabilidades[i]*100:.2f}%")

def selecao_proporcional(pop_avaliada, n_pop_selec):
    """
    Recebe: população avaliada e quantidade a selecionar
    Retorna: apenas os cromossomos selecionados (sem o valor da sphere)
    """
    fitness = calcular_fitness(pop_avaliada)

    grupo_survivors = random.choices(pop_avaliada, weights=fitness, k=n_pop_selec)
    
    # retorna só os cromossomos, sem o valor da sphere
    return [individuo[0] for individuo in grupo_survivors]

# %%
#mostrar_probabilidade(pop_aval)
#len(p1_survivors)

# %%
def selecao_torneio(pop_avaliada, n_pop_selec):
    """
    Recebe: população avaliada [(cromossomo, avaliação), ...]
    Retorna: lista de cromossomos selecionados via torneio
    """
    grupo_survivors = []
    for rodada in range(n_pop_selec):
        # sorteiar 2 competidores
        c1, c2 = random.choices(pop_avaliada, k=2)

        # mostrar os competidores
        #print(f"Torneio {rodada+1}:")
        #print(f"  Competidor 1 -> avaliação={c1[1]:.2f}")
        #print(f"  Competidor 2 -> avaliação={c2[1]:.2f}")

        # comparar avaliações (menor é melhor)
        if c1[1] < c2[1]:
            survivor = c1
        else:
            survivor = c2

        #print(f"  Vencedor -> avaliação={survivor[1]:.2f}\n")

        grupo_survivors.append(survivor[0])  # pega só o cromossomo

    return grupo_survivors

# %%
def selecionar_pais(selecao, pop_avaliada, n_pop_selec):
    """
    Recebe: lista de tuplas (cromossomo, valor_sphere)          
    :param selecao: 
    :param pop_avaliada: 
    :param n_pop_selec: 
    :return: lista de p1 e p2 selecionados
    """
    if selecao.lower().strip() == 'torneio':
        p1_survivors = selecao_torneio(pop_avaliada, n_pop_selec)
        p2_survivors= selecao_torneio(pop_avaliada, n_pop_selec)
    else:
        p1_survivors = selecao_proporcional(pop_avaliada, n_pop_selec)
        p2_survivors = selecao_proporcional(pop_avaliada, n_pop_selec)
    return p1_survivors, p2_survivors

# %%
def crossover_1pt(p1, p2, taxa_crossover, quantidade_genes):
    """
    Recebe: dois pais (Selecionados/sobreviventes), taxa de crossover e a quantidade de genes
    Retorna: dois filhos
    """
    # verifica se há cruzamento
    if random.random() < taxa_crossover:
        ponto_corte = random.randint(1, quantidade_genes - 1)
        
        # troca as partes após o ponto de corte
        filho1 = p1[:ponto_corte] + p2[ponto_corte:]
        filho2 = p2[:ponto_corte] + p1[ponto_corte:]
        #print(f"crossover: {filho1} + {filho2}\n")
    else:
        # sem cruzamento, filhos são cópias dos pais
        filho1 = p1[:]
        filho2 = p2[:]
        #print(f"sem crossover: {filho1} + {filho2}\n")
    
    return filho1, filho2

# %%
def mutacao(cromossomo, taxa_mutacao, quantidade_genes, var_min, var_max):
    """
    Recebe: cromossomo, quantidade de genes, taxa de mutação e limites
    Retorna: cromossomo (com possíveis mutações)
    """
    cromossomo_mutado = cromossomo[:]  # copia para não alterar o original
    
    for i in range(quantidade_genes):
        if random.random() < taxa_mutacao:
            cromossomo_mutado[i] = random.uniform(var_min, var_max)
            #print(f"mutacao no {i+1}: {cromossomo} ---> {cromossomo_mutado}\n")
    
    return cromossomo_mutado

# %%
def gerar_nova_pop(p1_survivors, p2_survivors, quantidade_genes,n_pop,
                          taxa_crossover, taxa_mutacao, 
                          var_min, var_max, nova_pop):
    """
    Recebe: listas de pais selecionados, quantidade de genes, a lista de nova populção, taxas e limites
    Retorna: nova população após crossover e mutação
    """
    
    # percorre os pais em pares
    for i in range(0, n_pop):
        
        p1 = random.choice(p1_survivors)
        p2 = random.choice(p2_survivors)
        
        # crossover
        filho1, filho2 = crossover_1pt(p1, p2, taxa_crossover, quantidade_genes)
        
        # mutação em cada filho
        filho1 = mutacao(filho1, taxa_mutacao, quantidade_genes, var_min, var_max)
        filho2 = mutacao(filho2, taxa_mutacao, quantidade_genes, var_min, var_max)
        
        nova_pop.append(filho1)
        nova_pop.append(filho2)
        
    return nova_pop

# %%
#nova_pop.clear()
#gerar_nova_pop(p1_survivors, p2_survivors, quantidade_genes, n_pop, taxa_crossover, taxa_mutacao, var_min, var_max, nova_pop)

# %%
#len(nova_pop)

# %%
#print(nova_pop)

# %% [markdown]
# ## Loop exec - Critério de parada - GERAÇÕES

# %% [markdown]
# Aqui a gente adicionou também o elitismo, nele os melhore índividuos de uma geração são copiados para a próxima (como uma seleção natural bem rígida). Isso garante que a qualidade da melhor solução encontrada nunca piore de uma geração para outra. A gente aplicou ele na Sphere (esfera) que significa que os n_elitismo primeiros (de menor valor) são salvos como elites. Os filhos gerados são avaliados e ordenados. Os 28 melhores são selecionados. A nova população é então montada colocando os 2 elites na frente, seguidos dos 28 melhores filhos.
#
# É isso que dá pra ver na célula abaixo:

# %%
funcoes_para_testar = {'Sphere': sphere, 'Rastrigin': rastrigin, 'Rosenbrock': rosenbrock}
resultados_globais = {}

for nome_func, funcao_atual in funcoes_para_testar.items():
    print(f"\n{'='*70}")
    print(f"INICIANDO TESTES PARA A FUNÇÃO: {nome_func.upper()}")
    print(f"{'='*70}\n")

    historico_melhor_all = []
    historico_notas_all = []
    melhor_fitness_por_exec = []

    for execucao in range(30):
        # Redefinir seed para reprodutibilidade com variação
        seed_atual = 42 + execucao
        random.seed(seed_atual)
        np.random.seed(seed_atual)
        
        # Reinicializar históricos para esta execução
        historico_melhor = []
        historico_notas = []
        
        # Gerar população inicial para esta execução
        pop.clear()
        for i in range(n_pop):
            cromossomo = [random.uniform(var_min, var_max) for _ in range(n_dimensoes)]
            pop.append(cromossomo)
        
        # Loop de gerações
        for geracao in range(n_geracoes):

            # 1. Avaliar população atual (usando a funcao_atual do loop)
            pop_aval = [(crom, funcao_atual(crom)) for crom in pop]

            notas_avaliacao = [aval for _, aval in pop_aval]
            historico_notas.append(notas_avaliacao)

            # 2. Elitismo: preservar os n_elitismo melhores
            pop_aval_ord = sorted(pop_aval, key=lambda x: x[1])
            elites = [ind[0] for ind in pop_aval_ord[:n_elitismo]]

            # 3. Selecionar pais
            p1_survivors, p2_survivors = selecionar_pais(selecao, pop_aval, n_pop)

            # 4. Gerar (n_pop - n_elitismo) filhos para abrir espaço para os elites
            nova_pop.clear()
            gerar_nova_pop(p1_survivors, p2_survivors, quantidade_genes, n_pop - n_elitismo,
                           taxa_crossover, taxa_mutacao, var_min, var_max, nova_pop)

            # 5. Avaliar filhos e ordenar
            filhos_aval = [(crom, funcao_atual(crom)) for crom in nova_pop]
            filhos_aval.sort(key=lambda x: x[1])
            melhores_filhos = [ind[0] for ind in filhos_aval[:n_pop - n_elitismo]]

            # 6. Nova população = elites + melhores filhos
            pop = elites + melhores_filhos

            # 7. Registrar o melhor fitness da geração (considerando elites também)
            melhor_fitness = min(funcao_atual(ind) for ind in pop)
            historico_melhor.append(melhor_fitness)
        
        # Armazenar resultados desta execução
        historico_melhor_all.append(historico_melhor)
        historico_notas_all.append(historico_notas)
        melhor_fitness_por_exec.append(min(historico_melhor))
        
        print(f"Execução {execucao+1:02d}/30 (seed={seed_atual:3d}) | Melhor fitness final: {min(historico_melhor):.2f}")

    # Resultado final consolidado da Função atual
    resultados_globais[nome_func] = {
        'melhor_all': historico_melhor_all,
        'notas_all': historico_notas_all,
        'fitness_final': melhor_fitness_por_exec
    }

    print(f"\n{'='*60}")
    print(f"RESULTADOS FINAIS APÓS 30 EXECUÇÕES - {nome_func.upper()}")
    print(f"{'='*60}")
    print(f"Melhor fitness geral:               {min(melhor_fitness_por_exec):.2f}")
    print(f"Pior fitness (máximo observado):    {max(melhor_fitness_por_exec):.2f}")
    print(f"Fitness médio:                      {np.mean(melhor_fitness_por_exec):.2f}")
    print(f"Desvio padrão:                      {np.std(melhor_fitness_por_exec):.2f}")
    print(f"Mediana:                            {np.median(melhor_fitness_por_exec):.2f}")
# Out:
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: SPHERE
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 16392.07
# Execução 02/30 (seed= 43) | Melhor fitness final: 9022.30
# Execução 03/30 (seed= 44) | Melhor fitness final: 18921.87
# Execução 04/30 (seed= 45) | Melhor fitness final: 17670.78
# Execução 05/30 (seed= 46) | Melhor fitness final: 16855.23
# Execução 06/30 (seed= 47) | Melhor fitness final: 14529.91
# Execução 07/30 (seed= 48) | Melhor fitness final: 9846.78
# Execução 08/30 (seed= 49) | Melhor fitness final: 15547.07
# Execução 09/30 (seed= 50) | Melhor fitness final: 13867.91
# Execução 10/30 (seed= 51) | Melhor fitness final: 21865.79
# Execução 11/30 (seed= 52) | Melhor fitness final: 17392.53
# Execução 12/30 (seed= 53) | Melhor fitness final: 14576.59
# Execução 13/30 (seed= 54) | Melhor fitness final: 14658.50
# Execução 14/30 (seed= 55) | Melhor fitness final: 16898.81
# Execução 15/30 (seed= 56) | Melhor fitness final: 19912.29
# Execução 16/30 (seed= 57) | Melhor fitness final: 22565.62
# Execução 17/30 (seed= 58) | Melhor fitness final: 13042.63
# Execução 18/30 (seed= 59) | Melhor fitness final: 16515.41
# Execução 19/30 (seed= 60) | Melhor fitness final: 15503.64
# Execução 20/30 (seed= 61) | Melhor fitness final: 15408.77
# Execução 21/30 (seed= 62) | Melhor fitness final: 15337.90
# Execução 22/30 (seed= 63) | Melhor fitness final: 17333.76
# Execução 23/30 (seed= 64) | Melhor fitness final: 19900.04
# Execução 24/30 (seed= 65) | Melhor fitness final: 12131.26
# Execução 25/30 (seed= 66) | Melhor fitness final: 13209.18
# Execução 26/30 (seed= 67) | Melhor fitness final: 18061.40
# Execução 27/30 (seed= 68) | Melhor fitness final: 14240.17
# Execução 28/30 (seed= 69) | Melhor fitness final: 12149.61
# Execução 29/30 (seed= 70) | Melhor fitness final: 14502.72
# Execução 30/30 (seed= 71) | Melhor fitness final: 13435.03
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - SPHERE
# ============================================================
# Melhor fitness geral:               9022.30
# Pior fitness (máximo observado):    22565.62
# Fitness médio:                      15709.85
# Desvio padrão:                      3073.15
# Mediana:                            15456.20
#
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: RASTRIGIN
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 17730.30
# Execução 02/30 (seed= 43) | Melhor fitness final: 8406.50
# Execução 03/30 (seed= 44) | Melhor fitness final: 20722.23
# Execução 04/30 (seed= 45) | Melhor fitness final: 15945.82
# Execução 05/30 (seed= 46) | Melhor fitness final: 17005.02
# Execução 06/30 (seed= 47) | Melhor fitness final: 15280.84
# Execução 07/30 (seed= 48) | Melhor fitness final: 12056.15
# Execução 08/30 (seed= 49) | Melhor fitness final: 13287.48
# Execução 09/30 (seed= 50) | Melhor fitness final: 16072.82
# Execução 10/30 (seed= 51) | Melhor fitness final: 17875.02
# Execução 11/30 (seed= 52) | Melhor fitness final: 18363.97
# Execução 12/30 (seed= 53) | Melhor fitness final: 11692.97
# Execução 13/30 (seed= 54) | Melhor fitness final: 18777.04
# Execução 14/30 (seed= 55) | Melhor fitness final: 16983.05
# Execução 15/30 (seed= 56) | Melhor fitness final: 10990.50
# Execução 16/30 (seed= 57) | Melhor fitness final: 21621.71
# Execução 17/30 (seed= 58) | Melhor fitness final: 13342.56
# Execução 18/30 (seed= 59) | Melhor fitness final: 14326.54
# Execução 19/30 (seed= 60) | Melhor fitness final: 14173.32
# Execução 20/30 (seed= 61) | Melhor fitness final: 14301.15
# Execução 21/30 (seed= 62) | Melhor fitness final: 16868.15
# Execução 22/30 (seed= 63) | Melhor fitness final: 17508.91
# Execução 23/30 (seed= 64) | Melhor fitness final: 16224.14
# Execução 24/30 (seed= 65) | Melhor fitness final: 13850.39
# Execução 25/30 (seed= 66) | Melhor fitness final: 15633.49
# Execução 26/30 (seed= 67) | Melhor fitness final: 17551.28
# Execução 27/30 (seed= 68) | Melhor fitness final: 11768.96
# Execução 28/30 (seed= 69) | Melhor fitness final: 13694.51
# Execução 29/30 (seed= 70) | Melhor fitness final: 15265.99
# Execução 30/30 (seed= 71) | Melhor fitness final: 13219.27
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - RASTRIGIN
# ============================================================
# Melhor fitness geral:               8406.50
# Pior fitness (máximo observado):    21621.71
# Fitness médio:                      15351.34
# Desvio padrão:                      2861.39
# Mediana:                            15457.16
#
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: ROSENBROCK
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 2766715406.04
# Execução 02/30 (seed= 43) | Melhor fitness final: 1739512600.65
# Execução 03/30 (seed= 44) | Melhor fitness final: 3481365121.78
# Execução 04/30 (seed= 45) | Melhor fitness final: 3187615092.63
# Execução 05/30 (seed= 46) | Melhor fitness final: 2170913516.29
# Execução 06/30 (seed= 47) | Melhor fitness final: 1905417273.11
# Execução 07/30 (seed= 48) | Melhor fitness final: 2511905348.74
# Execução 08/30 (seed= 49) | Melhor fitness final: 2772321418.31
# Execução 09/30 (seed= 50) | Melhor fitness final: 2819768115.36
# Execução 10/30 (seed= 51) | Melhor fitness final: 2858228716.11
# Execução 11/30 (seed= 52) | Melhor fitness final: 3367703689.49
# Execução 12/30 (seed= 53) | Melhor fitness final: 1290710534.03
# Execução 13/30 (seed= 54) | Melhor fitness final: 3263306598.79
# Execução 14/30 (seed= 55) | Melhor fitness final: 4056154271.30
# Execução 15/30 (seed= 56) | Melhor fitness final: 2371206843.25
# Execução 16/30 (seed= 57) | Melhor fitness final: 2945234330.85
# Execução 17/30 (seed= 58) | Melhor fitness final: 1997640936.02
# Execução 18/30 (seed= 59) | Melhor fitness final: 1066569667.23
# Execução 19/30 (seed= 60) | Melhor fitness final: 3510294845.82
# Execução 20/30 (seed= 61) | Melhor fitness final: 2254218658.66
# Execução 21/30 (seed= 62) | Melhor fitness final: 3847184162.11
# Execução 22/30 (seed= 63) | Melhor fitness final: 2468360043.61
# Execução 23/30 (seed= 64) | Melhor fitness final: 2712525036.12
# Execução 24/30 (seed= 65) | Melhor fitness final: 2065217149.03
# Execução 25/30 (seed= 66) | Melhor fitness final: 2489195702.08
# Execução 26/30 (seed= 67) | Melhor fitness final: 2132911198.68
# Execução 27/30 (seed= 68) | Melhor fitness final: 2152845151.79
# Execução 28/30 (seed= 69) | Melhor fitness final: 2274859122.81
# Execução 29/30 (seed= 70) | Melhor fitness final: 2583813355.00
# Execução 30/30 (seed= 71) | Melhor fitness final: 2884388957.61
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - ROSENBROCK
# ============================================================
# Melhor fitness geral:               1066569667.23
# Pior fitness (máximo observado):    4056154271.30
# Fitness médio:                      2598270095.44
# Desvio padrão:                      680585227.45
# Mediana:                            2547859351.87

# %% [markdown]
# ## Gráficos

# %%
for nome_func, dados in resultados_globais.items():
    # Recuperando os dados da função atual
    historico_melhor_all = dados['melhor_all']
    historico_notas_all = dados['notas_all']
    melhor_fitness_por_exec = dados['fitness_final']
    
    melhor_por_geracao = []
    for geracao in range(n_geracoes):
        valores = [historico[geracao] for historico in historico_melhor_all]
        melhor_por_geracao.append(np.mean(valores))

    media_geral_por_geracao = []
    for geracao in range(n_geracoes):
        valores = []
        for historico in historico_notas_all:
            valores.extend(historico[geracao])
        media_geral_por_geracao.append(np.mean(valores))

    desvio_melhor = []
    for geracao in range(n_geracoes):
        valores = [historico[geracao] for historico in historico_melhor_all]
        desvio_melhor.append(np.std(valores))

    plt.figure(figsize=(14, 5))

    # Gráfico 1: Convergência
    plt.subplot(1, 2, 1)
    plt.plot(range(1, n_geracoes+1), melhor_por_geracao, label="Melhor (Média das 30)", linewidth=2, color='blue')
    plt.fill_between(range(1, n_geracoes+1), 
                      np.array(melhor_por_geracao) - np.array(desvio_melhor),
                      np.array(melhor_por_geracao) + np.array(desvio_melhor),
                      alpha=0.3, label="±1 Desvio Padrão", color='blue')
    plt.plot(range(1, n_geracoes+1), media_geral_por_geracao, label="Média Geral (30 exec)", linestyle="--", linewidth=2, color='orange')
    plt.xlabel("Geração")
    plt.ylabel("Fitness")
    plt.title(f"Convergência: {nome_func} ({n_geracoes} ger × 30 exec)")
    plt.yscale('symlog') 
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Gráfico 2: Boxplot
    plt.subplot(1, 2, 2)
    bp = plt.boxplot([melhor_fitness_por_exec], labels=[f'{nome_func} - 30 Exec'], patch_artist=True, widths=0.5)
    for patch in bp['boxes']:
        patch.set_facecolor('lightblue')
    plt.ylabel("Melhor Fitness Final")
    plt.title(f"Distribuição: {nome_func}")
    plt.yscale('symlog') 
    plt.grid(True, alpha=0.3, axis='y')

    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\melis\AppData\Local\Temp\ipykernel_47628\3777347161.py:43: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot([melhor_fitness_por_exec], labels=[f'{nome_func} - 30 Exec'], patch_artist=True, widths=0.5)
# C:\Users\melis\AppData\Local\Temp\ipykernel_47628\3777347161.py:43: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot([melhor_fitness_por_exec], labels=[f'{nome_func} - 30 Exec'], patch_artist=True, widths=0.5)
# C:\Users\melis\AppData\Local\Temp\ipykernel_47628\3777347161.py:43: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot([melhor_fitness_por_exec], labels=[f'{nome_func} - 30 Exec'], patch_artist=True, widths=0.5)
