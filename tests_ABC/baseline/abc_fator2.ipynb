# %%
import math
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# # functions

# %%
def sphere(x):
    """Mínimo global: f(0, ..., 0) = 0"""
    return sum(xi**2 for xi in x)

def rastrigin(x):
    """Mínimo global: f(0, ..., 0) = 0"""
    n = len(x)
    return 10 * n + sum(xi**2 - 10 * np.cos(2 * np.pi * xi) for xi in x)

def rosenbrock(x):
    """Mínimo global: f(1, ..., 1) = 0"""
    return sum(100 * (x[i+1] - x[i]**2)**2 + (x[i] - 1)**2 for i in range(len(x)-1))

# %% [markdown]
# # parameters

# %%
DIMENSIONS = 30              # Número de dimensões do espaço de busca (DIM)
GLOBAL_BEST = 0              # Melhor valor global conhecido
CS = 30                      # Tamanho da Colônia (Colony Size)
CICLOS = 100                 # Número de iterações/ciclos do algoritmo
RANDOM_SEED = 42             # Semente aleatória para reprodutibilidade
EXECUTIONS = 30              # Número de execuções para cada função
CONVERGENCE = 1e-5           # Critério de convergência

# Cálculo dinâmico do fator de abandono conforme solicitado: ((CS / 2) * DIM) / 2 e ((CS / 2) * DIM) / 4
FATOR_ABANDONO = ((CS / 2) * DIMENSIONS)

SELECTION_MODE = 'tournament' # Escolha entre 'roulette' (roleta) ou 'tournament' (torneio)
TOURNAMENT_SIZE = 3          # Quantidade de abelhas no torneio

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # bees

# %%
def get_fitness(value):
    """Calcula a aptidão: menores valores de custo resultam em maior fitness."""
    if value >= 0:
        return 1 / (value + 1)
    else:
        return 1 + abs(value)

def selection(bees, mode='roulette'):
    """Seleção de abelhas operárias pelas observadoras com base em Roleta ou Torneio."""
    if mode == 'roulette':
        fitnesses = [b.fitness for b in bees]
        total_fitness = sum(fitnesses)
        probs = [f / total_fitness for f in fitnesses]
        return np.random.choice(bees, p=probs)
    elif mode == 'tournament':
        competitors = random.sample(bees, TOURNAMENT_SIZE)
        return max(competitors, key=lambda b: b.fitness)

class Bee():
    def __init__(self, b_lo, b_hi, actual_function):
        self.b_lo = b_lo
        self.b_hi = b_hi
        self.actual_function = actual_function
        self.pos = np.random.uniform(b_lo, b_hi, DIMENSIONS)
        self.value = self.actual_function(self.pos)
        self.fitness = get_fitness(self.value)
        self.trials = 0

    def explore(self, target_pos, neighbor_pos):
        """
        Gera uma nova posição variando os dados da equação clássica do ABC:
        v_ij = x_ij + phi * (x_ij - x_kj)
        """
        new_pos = target_pos.copy()
        
        j = random.randint(0, DIMENSIONS - 1)
        phi = random.uniform(-1, 1)
        
        new_pos[j] = target_pos[j] + phi * (target_pos[j] - neighbor_pos[j])
        new_pos[j] = max(self.b_lo, min(self.b_hi, new_pos[j]))
        
        new_value = self.actual_function(new_pos)
        new_fitness = get_fitness(new_value)
        
        if new_fitness > self.fitness:
            self.pos = new_pos
            self.value = new_value
            self.fitness = new_fitness
            self.trials = 0
        else:
            self.trials += 1

    def reset(self):
        """Fase da Escoteira: Reinicializa se exceder o FATOR_ABANDONO."""
        self.pos = np.random.uniform(self.b_lo, self.b_hi, DIMENSIONS)
        self.value = self.actual_function(self.pos)
        self.fitness = get_fitness(self.value)
        self.trials = 0

# %% [markdown]
# # problem

# %%
def artificial_bee_colony(selection_mode='roulette'):
    resultados_finais = {}

    for actual_function in [sphere, rastrigin, rosenbrock]:
        print(f"\n{'='*70}")
        print(f"INICIANDO TESTES PARA A FUNÇÃO: {actual_function.__name__.upper()}")
        print(f"{'='*70}\n")
        
        # Limites do espaço de busca
        if actual_function.__name__ == 'rastrigin':
            b_lo, b_hi = -5.12, 5.12
        elif actual_function.__name__ == 'rosenbrock':
            b_lo, b_hi = -30.0, 30.0
        else:
            b_lo, b_hi = -100.0, 100.0

        curvas_desta_funcao = []
        melhor_fitness_por_exec = [] # Armazena o melhor resultado de cada uma das 30 rodadas

        for execution in range(EXECUTIONS):
            convergence_curve = []
            
            seed_atual = RANDOM_SEED + execution
            random.seed(seed_atual)
            np.random.seed(seed_atual)
            
            # Divisão da colônia (Metade operárias, metade observadoras)
            num_employees = CS // 2
            employees = [Bee(b_lo, b_hi, actual_function) for _ in range(num_employees)]
            onlookers = [Bee(b_lo, b_hi, actual_function) for _ in range(CS - num_employees)]
            
            best_value = math.inf
            
            curr_iter = 0
            while curr_iter < CICLOS:
                
                # 1. Fase das Abelhas Operárias
                for i, bee in enumerate(employees):
                    k = random.choice([x for x in range(num_employees) if x != i])
                    neighbor_pos = employees[k].pos
                    bee.explore(target_pos=bee.pos, neighbor_pos=neighbor_pos)
                
                # 2. Fase das Abelhas Observadoras
                for bee in onlookers:
                    chosen_employee = selection(employees, mode=selection_mode)
                    k = random.randint(0, num_employees - 1)
                    neighbor_pos = employees[k].pos
                    bee.explore(target_pos=chosen_employee.pos, neighbor_pos=neighbor_pos)
                
                # 3. Fase das Escoteiras (Verifica o limite de abandono)
                for bee in employees + onlookers:
                    if bee.trials >= FATOR_ABANDONO:
                        bee.reset()
                        
                # 4. Atualiza a melhor solução global
                current_best = min(employees + onlookers, key=lambda b: b.value).value
                if current_best < best_value:
                    best_value = current_best
                    
                convergence_curve.append(best_value)
                
                # Critério de Parada Antecipada por Convergência
                if abs(best_value - GLOBAL_BEST) < CONVERGENCE:
                    resto_iters = CICLOS - curr_iter - 1
                    convergence_curve.extend([best_value] * resto_iters)
                    break
                    
                curr_iter += 1

            # Salvar resultados da execução
            curvas_desta_funcao.append(convergence_curve)
            melhor_fitness_por_exec.append(best_value)
            
            print(f"Execução {execution+1:02d}/{EXECUTIONS} (seed={seed_atual:3d}) | Melhor fitness final: {best_value:.2f}")
        
        # Calcular a média das curvas para o gráfico
        media_curvas = np.mean(curvas_desta_funcao, axis=0)
        resultados_finais[actual_function.__name__] = media_curvas
        
        # Impressão do Bloco Estatístico (Cópia exata do padrão do AG)
        print(f"\n{'='*60}")
        print(f"RESULTADOS FINAIS APÓS {EXECUTIONS} EXECUÇÕES - {actual_function.__name__.upper()}")
        print(f"{'='*60}")
        print(f"Melhor fitness geral:               {np.min(melhor_fitness_por_exec):.2f}")
        print(f"Pior fitness (máximo observado):    {np.max(melhor_fitness_por_exec):.2f}")
        print(f"Fitness médio:                      {np.mean(melhor_fitness_por_exec):.2f}")
        print(f"Desvio padrão:                      {np.std(melhor_fitness_por_exec):.2f}")
        print(f"Mediana:                            {np.median(melhor_fitness_por_exec):.2f}")

    # Geração dos gráficos ao final de todos os testes
    plt.figure(figsize=(10, 6))
    for nome_funcao, media_curva in resultados_finais.items():
        curva_segura = [max(val, 1e-10) for val in media_curva]
        plt.plot(curva_segura, label=nome_funcao.capitalize(), linewidth=2)

    plt.title(f"Curva de Convergência Média ABC ({EXECUTIONS} Execuções - {DIMENSIONS}D)")
    plt.xlabel("Iterações")
    plt.ylabel("Melhor Custo (Z) - Escala Log")
    plt.yscale("log")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#rodar
artificial_bee_colony(selection_mode=SELECTION_MODE)
# Out:
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: SPHERE
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 13684.94
# Execução 02/30 (seed= 43) | Melhor fitness final: 17292.48
# Execução 03/30 (seed= 44) | Melhor fitness final: 19163.31
# Execução 04/30 (seed= 45) | Melhor fitness final: 24430.55
# Execução 05/30 (seed= 46) | Melhor fitness final: 17123.23
# Execução 06/30 (seed= 47) | Melhor fitness final: 27000.77
# Execução 07/30 (seed= 48) | Melhor fitness final: 18085.82
# Execução 08/30 (seed= 49) | Melhor fitness final: 20793.54
# Execução 09/30 (seed= 50) | Melhor fitness final: 17099.79
# Execução 10/30 (seed= 51) | Melhor fitness final: 23896.22
# Execução 11/30 (seed= 52) | Melhor fitness final: 18550.96
# Execução 12/30 (seed= 53) | Melhor fitness final: 16943.82
# Execução 13/30 (seed= 54) | Melhor fitness final: 17074.87
# Execução 14/30 (seed= 55) | Melhor fitness final: 14594.63
# Execução 15/30 (seed= 56) | Melhor fitness final: 26192.12
# Execução 16/30 (seed= 57) | Melhor fitness final: 23496.54
# Execução 17/30 (seed= 58) | Melhor fitness final: 21015.66
# Execução 18/30 (seed= 59) | Melhor fitness final: 18870.55
# Execução 19/30 (seed= 60) | Melhor fitness final: 21346.14
# Execução 20/30 (seed= 61) | Melhor fitness final: 13606.07
# Execução 21/30 (seed= 62) | Melhor fitness final: 16240.83
# Execução 22/30 (seed= 63) | Melhor fitness final: 23029.55
# Execução 23/30 (seed= 64) | Melhor fitness final: 20082.88
# Execução 24/30 (seed= 65) | Melhor fitness final: 28941.54
# Execução 25/30 (seed= 66) | Melhor fitness final: 28381.88
# Execução 26/30 (seed= 67) | Melhor fitness final: 24071.98
# Execução 27/30 (seed= 68) | Melhor fitness final: 17725.34
# Execução 28/30 (seed= 69) | Melhor fitness final: 13450.60
# Execução 29/30 (seed= 70) | Melhor fitness final: 23927.36
# Execução 30/30 (seed= 71) | Melhor fitness final: 14144.51
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - SPHERE
# ============================================================
# Melhor fitness geral:               13450.60
# Pior fitness (máximo observado):    28941.54
# Fitness médio:                      20008.62
# Desvio padrão:                      4417.31
# Mediana:                            19016.93
#
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: RASTRIGIN
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 199.62
# Execução 02/30 (seed= 43) | Melhor fitness final: 230.65
# Execução 03/30 (seed= 44) | Melhor fitness final: 211.73
# Execução 04/30 (seed= 45) | Melhor fitness final: 221.80
# Execução 05/30 (seed= 46) | Melhor fitness final: 230.03
# Execução 06/30 (seed= 47) | Melhor fitness final: 202.20
# Execução 07/30 (seed= 48) | Melhor fitness final: 214.67
# Execução 08/30 (seed= 49) | Melhor fitness final: 201.43
# Execução 09/30 (seed= 50) | Melhor fitness final: 203.91
# Execução 10/30 (seed= 51) | Melhor fitness final: 208.82
# Execução 11/30 (seed= 52) | Melhor fitness final: 165.31
# Execução 12/30 (seed= 53) | Melhor fitness final: 237.82
# Execução 13/30 (seed= 54) | Melhor fitness final: 192.04
# Execução 14/30 (seed= 55) | Melhor fitness final: 206.28
# Execução 15/30 (seed= 56) | Melhor fitness final: 224.34
# Execução 16/30 (seed= 57) | Melhor fitness final: 186.06
# Execução 17/30 (seed= 58) | Melhor fitness final: 230.07
# Execução 18/30 (seed= 59) | Melhor fitness final: 219.00
# Execução 19/30 (seed= 60) | Melhor fitness final: 159.73
# Execução 20/30 (seed= 61) | Melhor fitness final: 193.01
# Execução 21/30 (seed= 62) | Melhor fitness final: 187.15
# Execução 22/30 (seed= 63) | Melhor fitness final: 165.08
# Execução 23/30 (seed= 64) | Melhor fitness final: 208.17
# Execução 24/30 (seed= 65) | Melhor fitness final: 228.15
# Execução 25/30 (seed= 66) | Melhor fitness final: 193.97
# Execução 26/30 (seed= 67) | Melhor fitness final: 205.62
# Execução 27/30 (seed= 68) | Melhor fitness final: 218.98
# Execução 28/30 (seed= 69) | Melhor fitness final: 170.48
# Execução 29/30 (seed= 70) | Melhor fitness final: 216.36
# Execução 30/30 (seed= 71) | Melhor fitness final: 213.51
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - RASTRIGIN
# ============================================================
# Melhor fitness geral:               159.73
# Pior fitness (máximo observado):    237.82
# Fitness médio:                      204.87
# Desvio padrão:                      20.42
# Mediana:                            207.23
#
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: ROSENBROCK
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 18426509.82
# Execução 02/30 (seed= 43) | Melhor fitness final: 33263089.47
# Execução 03/30 (seed= 44) | Melhor fitness final: 29535649.14
# Execução 04/30 (seed= 45) | Melhor fitness final: 43513754.34
# Execução 05/30 (seed= 46) | Melhor fitness final: 25947345.15
# Execução 06/30 (seed= 47) | Melhor fitness final: 65772626.77
# Execução 07/30 (seed= 48) | Melhor fitness final: 48070521.63
# Execução 08/30 (seed= 49) | Melhor fitness final: 31182392.83
# Execução 09/30 (seed= 50) | Melhor fitness final: 22150930.29
# Execução 10/30 (seed= 51) | Melhor fitness final: 52315010.61
# Execução 11/30 (seed= 52) | Melhor fitness final: 25156298.49
# Execução 12/30 (seed= 53) | Melhor fitness final: 38352991.22
# Execução 13/30 (seed= 54) | Melhor fitness final: 42418519.55
# Execução 14/30 (seed= 55) | Melhor fitness final: 19543217.28
# Execução 15/30 (seed= 56) | Melhor fitness final: 69395737.85
# Execução 16/30 (seed= 57) | Melhor fitness final: 43088604.61
# Execução 17/30 (seed= 58) | Melhor fitness final: 43715873.86
# Execução 18/30 (seed= 59) | Melhor fitness final: 35702673.30
# Execução 19/30 (seed= 60) | Melhor fitness final: 38096415.17
# Execução 20/30 (seed= 61) | Melhor fitness final: 22332638.76
# Execução 21/30 (seed= 62) | Melhor fitness final: 41317128.00
# Execução 22/30 (seed= 63) | Melhor fitness final: 43939592.67
# Execução 23/30 (seed= 64) | Melhor fitness final: 29536693.21
# Execução 24/30 (seed= 65) | Melhor fitness final: 62245350.67
# Execução 25/30 (seed= 66) | Melhor fitness final: 58166113.05
# Execução 26/30 (seed= 67) | Melhor fitness final: 58255898.30
# Execução 27/30 (seed= 68) | Melhor fitness final: 28845563.76
# Execução 28/30 (seed= 69) | Melhor fitness final: 16128469.10
# Execução 29/30 (seed= 70) | Melhor fitness final: 57054508.07
# Execução 30/30 (seed= 71) | Melhor fitness final: 16202530.02
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - ROSENBROCK
# ============================================================
# Melhor fitness geral:               16128469.10
# Pior fitness (máximo observado):    69395737.85
# Fitness médio:                      38655754.90
# Desvio padrão:                      15009622.45
# Mediana:                            38224703.19
