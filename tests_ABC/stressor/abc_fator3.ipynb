# %%
import math
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# # functions

# %%
def sphere(x):
    """Mínimo global: f(0, ..., 0) = 0"""
    return sum(xi**2 for xi in x)

def rastrigin(x):
    """Mínimo global: f(0, ..., 0) = 0"""
    n = len(x)
    return 10 * n + sum(xi**2 - 10 * np.cos(2 * np.pi * xi) for xi in x)

def rosenbrock(x):
    """Mínimo global: f(1, ..., 1) = 0"""
    return sum(100 * (x[i+1] - x[i]**2)**2 + (x[i] - 1)**2 for i in range(len(x)-1))

# %% [markdown]
# # parameters

# %%
DIMENSIONS = 30              # Número de dimensões do espaço de busca (DIM)
GLOBAL_BEST = 0              # Melhor valor global conhecido
CS = 100                      # Tamanho da Colônia (Colony Size)
CICLOS = 500                 # Número de iterações/ciclos do algoritmo
RANDOM_SEED = 42             # Semente aleatória para reprodutibilidade
EXECUTIONS = 30              # Número de execuções para cada função
CONVERGENCE = 1e-5           # Critério de convergência

# Cálculo dinâmico do fator de abandono conforme solicitado: ((CS / 2) * DIM) / 2 e ((CS / 2) * DIM) / 4
FATOR_ABANDONO = ((CS / 2) * DIMENSIONS)

SELECTION_MODE = 'roulette' # Escolha entre 'roulette' (roleta) ou 'tournament' (torneio)
TOURNAMENT_SIZE = 3          # Quantidade de abelhas no torneio

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # bees

# %%
def get_fitness(value):
    """Calcula a aptidão: menores valores de custo resultam em maior fitness."""
    if value >= 0:
        return 1 / (value + 1)
    else:
        return 1 + abs(value)

def selection(bees, mode='roulette'):
    """Seleção de abelhas operárias pelas observadoras com base em Roleta ou Torneio."""
    if mode == 'roulette':
        fitnesses = [b.fitness for b in bees]
        total_fitness = sum(fitnesses)
        probs = [f / total_fitness for f in fitnesses]
        return np.random.choice(bees, p=probs)
    elif mode == 'tournament':
        competitors = random.sample(bees, TOURNAMENT_SIZE)
        return max(competitors, key=lambda b: b.fitness)

class Bee():
    def __init__(self, b_lo, b_hi, actual_function):
        self.b_lo = b_lo
        self.b_hi = b_hi
        self.actual_function = actual_function
        self.pos = np.random.uniform(b_lo, b_hi, DIMENSIONS)
        self.value = self.actual_function(self.pos)
        self.fitness = get_fitness(self.value)
        self.trials = 0

    def explore(self, target_pos, neighbor_pos):
        """
        Gera uma nova posição variando os dados da equação clássica do ABC:
        v_ij = x_ij + phi * (x_ij - x_kj)
        """
        new_pos = target_pos.copy()
        
        j = random.randint(0, DIMENSIONS - 1)
        phi = random.uniform(-1, 1)
        
        new_pos[j] = target_pos[j] + phi * (target_pos[j] - neighbor_pos[j])
        new_pos[j] = max(self.b_lo, min(self.b_hi, new_pos[j]))
        
        new_value = self.actual_function(new_pos)
        new_fitness = get_fitness(new_value)
        
        if new_fitness > self.fitness:
            self.pos = new_pos
            self.value = new_value
            self.fitness = new_fitness
            self.trials = 0
        else:
            self.trials += 1

    def reset(self):
        """Fase da Escoteira: Reinicializa se exceder o FATOR_ABANDONO."""
        self.pos = np.random.uniform(self.b_lo, self.b_hi, DIMENSIONS)
        self.value = self.actual_function(self.pos)
        self.fitness = get_fitness(self.value)
        self.trials = 0

# %% [markdown]
# # problem

# %%
def artificial_bee_colony(selection_mode='roulette'):
    resultados_finais = {}

    for actual_function in [sphere, rastrigin, rosenbrock]:
        print(f"\n{'='*70}")
        print(f"INICIANDO TESTES PARA A FUNÇÃO: {actual_function.__name__.upper()}")
        print(f"{'='*70}\n")
        
        # Limites do espaço de busca
        if actual_function.__name__ == 'rastrigin':
            b_lo, b_hi = -5.12, 5.12
        elif actual_function.__name__ == 'rosenbrock':
            b_lo, b_hi = -30.0, 30.0
        else:
            b_lo, b_hi = -100.0, 100.0

        curvas_desta_funcao = []
        melhor_fitness_por_exec = [] # Armazena o melhor resultado de cada uma das 30 rodadas

        for execution in range(EXECUTIONS):
            convergence_curve = []
            
            seed_atual = RANDOM_SEED + execution
            random.seed(seed_atual)
            np.random.seed(seed_atual)
            
            # Divisão da colônia (Metade operárias, metade observadoras)
            num_employees = CS // 2
            employees = [Bee(b_lo, b_hi, actual_function) for _ in range(num_employees)]
            onlookers = [Bee(b_lo, b_hi, actual_function) for _ in range(CS - num_employees)]
            
            best_value = math.inf
            
            curr_iter = 0
            while curr_iter < CICLOS:
                
                # 1. Fase das Abelhas Operárias
                for i, bee in enumerate(employees):
                    k = random.choice([x for x in range(num_employees) if x != i])
                    neighbor_pos = employees[k].pos
                    bee.explore(target_pos=bee.pos, neighbor_pos=neighbor_pos)
                
                # 2. Fase das Abelhas Observadoras
                for bee in onlookers:
                    chosen_employee = selection(employees, mode=selection_mode)
                    k = random.randint(0, num_employees - 1)
                    neighbor_pos = employees[k].pos
                    bee.explore(target_pos=chosen_employee.pos, neighbor_pos=neighbor_pos)
                
                # 3. Fase das Escoteiras (Verifica o limite de abandono)
                for bee in employees + onlookers:
                    if bee.trials >= FATOR_ABANDONO:
                        bee.reset()
                        
                # 4. Atualiza a melhor solução global
                current_best = min(employees + onlookers, key=lambda b: b.value).value
                if current_best < best_value:
                    best_value = current_best
                    
                convergence_curve.append(best_value)
                
                # Critério de Parada Antecipada por Convergência
                if abs(best_value - GLOBAL_BEST) < CONVERGENCE:
                    resto_iters = CICLOS - curr_iter - 1
                    convergence_curve.extend([best_value] * resto_iters)
                    break
                    
                curr_iter += 1

            # Salvar resultados da execução
            curvas_desta_funcao.append(convergence_curve)
            melhor_fitness_por_exec.append(best_value)
            
            print(f"Execução {execution+1:02d}/{EXECUTIONS} (seed={seed_atual:3d}) | Melhor fitness final: {best_value:.2f}")
        
        # Calcular a média das curvas para o gráfico
        media_curvas = np.mean(curvas_desta_funcao, axis=0)
        resultados_finais[actual_function.__name__] = media_curvas
        
        # Impressão do Bloco Estatístico (Cópia exata do padrão do AG)
        print(f"\n{'='*60}")
        print(f"RESULTADOS FINAIS APÓS {EXECUTIONS} EXECUÇÕES - {actual_function.__name__.upper()}")
        print(f"{'='*60}")
        print(f"Melhor fitness geral:               {np.min(melhor_fitness_por_exec):.2f}")
        print(f"Pior fitness (máximo observado):    {np.max(melhor_fitness_por_exec):.2f}")
        print(f"Fitness médio:                      {np.mean(melhor_fitness_por_exec):.2f}")
        print(f"Desvio padrão:                      {np.std(melhor_fitness_por_exec):.2f}")
        print(f"Mediana:                            {np.median(melhor_fitness_por_exec):.2f}")

    # Geração dos gráficos ao final de todos os testes
    plt.figure(figsize=(10, 6))
    for nome_funcao, media_curva in resultados_finais.items():
        curva_segura = [max(val, 1e-10) for val in media_curva]
        plt.plot(curva_segura, label=nome_funcao.capitalize(), linewidth=2)

    plt.title(f"Curva de Convergência Média ABC ({EXECUTIONS} Execuções - {DIMENSIONS}D)")
    plt.xlabel("Iterações")
    plt.ylabel("Melhor Custo (Z) - Escala Log")
    plt.yscale("log")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#rodar
artificial_bee_colony(selection_mode=SELECTION_MODE)
# Out:
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: SPHERE
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 10.05
# Execução 02/30 (seed= 43) | Melhor fitness final: 4.40
# Execução 03/30 (seed= 44) | Melhor fitness final: 5.62
# Execução 04/30 (seed= 45) | Melhor fitness final: 3.80
# Execução 05/30 (seed= 46) | Melhor fitness final: 13.59
# Execução 06/30 (seed= 47) | Melhor fitness final: 6.94
# Execução 07/30 (seed= 48) | Melhor fitness final: 9.04
# Execução 08/30 (seed= 49) | Melhor fitness final: 6.64
# Execução 09/30 (seed= 50) | Melhor fitness final: 15.39
# Execução 10/30 (seed= 51) | Melhor fitness final: 0.56
# Execução 11/30 (seed= 52) | Melhor fitness final: 7.27
# Execução 12/30 (seed= 53) | Melhor fitness final: 4.79
# Execução 13/30 (seed= 54) | Melhor fitness final: 2.65
# Execução 14/30 (seed= 55) | Melhor fitness final: 10.62
# Execução 15/30 (seed= 56) | Melhor fitness final: 10.31
# Execução 16/30 (seed= 57) | Melhor fitness final: 11.49
# Execução 17/30 (seed= 58) | Melhor fitness final: 4.35
# Execução 18/30 (seed= 59) | Melhor fitness final: 7.41
# Execução 19/30 (seed= 60) | Melhor fitness final: 7.65
# Execução 20/30 (seed= 61) | Melhor fitness final: 6.18
# Execução 21/30 (seed= 62) | Melhor fitness final: 5.60
# Execução 22/30 (seed= 63) | Melhor fitness final: 4.21
# Execução 23/30 (seed= 64) | Melhor fitness final: 14.77
# Execução 24/30 (seed= 65) | Melhor fitness final: 22.10
# Execução 25/30 (seed= 66) | Melhor fitness final: 5.94
# Execução 26/30 (seed= 67) | Melhor fitness final: 10.73
# Execução 27/30 (seed= 68) | Melhor fitness final: 5.51
# Execução 28/30 (seed= 69) | Melhor fitness final: 5.18
# Execução 29/30 (seed= 70) | Melhor fitness final: 7.24
# Execução 30/30 (seed= 71) | Melhor fitness final: 3.95
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - SPHERE
# ============================================================
# Melhor fitness geral:               0.56
# Pior fitness (máximo observado):    22.10
# Fitness médio:                      7.80
# Desvio padrão:                      4.37
# Mediana:                            6.79
#
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: RASTRIGIN
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 24.57
# Execução 02/30 (seed= 43) | Melhor fitness final: 29.85
# Execução 03/30 (seed= 44) | Melhor fitness final: 27.42
# Execução 04/30 (seed= 45) | Melhor fitness final: 24.71
# Execução 05/30 (seed= 46) | Melhor fitness final: 33.08
# Execução 06/30 (seed= 47) | Melhor fitness final: 30.25
# Execução 07/30 (seed= 48) | Melhor fitness final: 24.49
# Execução 08/30 (seed= 49) | Melhor fitness final: 29.20
# Execução 09/30 (seed= 50) | Melhor fitness final: 28.64
# Execução 10/30 (seed= 51) | Melhor fitness final: 28.13
# Execução 11/30 (seed= 52) | Melhor fitness final: 26.28
# Execução 12/30 (seed= 53) | Melhor fitness final: 23.28
# Execução 13/30 (seed= 54) | Melhor fitness final: 20.64
# Execução 14/30 (seed= 55) | Melhor fitness final: 26.33
# Execução 15/30 (seed= 56) | Melhor fitness final: 21.77
# Execução 16/30 (seed= 57) | Melhor fitness final: 26.01
# Execução 17/30 (seed= 58) | Melhor fitness final: 32.36
# Execução 18/30 (seed= 59) | Melhor fitness final: 26.24
# Execução 19/30 (seed= 60) | Melhor fitness final: 20.70
# Execução 20/30 (seed= 61) | Melhor fitness final: 24.95
# Execução 21/30 (seed= 62) | Melhor fitness final: 24.92
# Execução 22/30 (seed= 63) | Melhor fitness final: 25.87
# Execução 23/30 (seed= 64) | Melhor fitness final: 35.94
# Execução 24/30 (seed= 65) | Melhor fitness final: 32.01
# Execução 25/30 (seed= 66) | Melhor fitness final: 26.85
# Execução 26/30 (seed= 67) | Melhor fitness final: 31.08
# Execução 27/30 (seed= 68) | Melhor fitness final: 27.25
# Execução 28/30 (seed= 69) | Melhor fitness final: 25.38
# Execução 29/30 (seed= 70) | Melhor fitness final: 30.77
# Execução 30/30 (seed= 71) | Melhor fitness final: 27.12
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - RASTRIGIN
# ============================================================
# Melhor fitness geral:               20.64
# Pior fitness (máximo observado):    35.94
# Fitness médio:                      27.20
# Desvio padrão:                      3.57
# Mediana:                            26.59
#
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: ROSENBROCK
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 3113.60
# Execução 02/30 (seed= 43) | Melhor fitness final: 2983.55
# Execução 03/30 (seed= 44) | Melhor fitness final: 4366.78
# Execução 04/30 (seed= 45) | Melhor fitness final: 4066.97
# Execução 05/30 (seed= 46) | Melhor fitness final: 2415.56
# Execução 06/30 (seed= 47) | Melhor fitness final: 3996.20
# Execução 07/30 (seed= 48) | Melhor fitness final: 4337.70
# Execução 08/30 (seed= 49) | Melhor fitness final: 3069.35
# Execução 09/30 (seed= 50) | Melhor fitness final: 2774.42
# Execução 10/30 (seed= 51) | Melhor fitness final: 4094.97
# Execução 11/30 (seed= 52) | Melhor fitness final: 4286.58
# Execução 12/30 (seed= 53) | Melhor fitness final: 1714.16
# Execução 13/30 (seed= 54) | Melhor fitness final: 2802.06
# Execução 14/30 (seed= 55) | Melhor fitness final: 2724.53
# Execução 15/30 (seed= 56) | Melhor fitness final: 1710.68
# Execução 16/30 (seed= 57) | Melhor fitness final: 5400.27
# Execução 17/30 (seed= 58) | Melhor fitness final: 3947.94
# Execução 18/30 (seed= 59) | Melhor fitness final: 4321.01
# Execução 19/30 (seed= 60) | Melhor fitness final: 4233.22
# Execução 20/30 (seed= 61) | Melhor fitness final: 2656.30
# Execução 21/30 (seed= 62) | Melhor fitness final: 4076.55
# Execução 22/30 (seed= 63) | Melhor fitness final: 4839.79
# Execução 23/30 (seed= 64) | Melhor fitness final: 3051.96
# Execução 24/30 (seed= 65) | Melhor fitness final: 3370.56
# Execução 25/30 (seed= 66) | Melhor fitness final: 1539.32
# Execução 26/30 (seed= 67) | Melhor fitness final: 2084.50
# Execução 27/30 (seed= 68) | Melhor fitness final: 2551.74
# Execução 28/30 (seed= 69) | Melhor fitness final: 3062.22
# Execução 29/30 (seed= 70) | Melhor fitness final: 5637.07
# Execução 30/30 (seed= 71) | Melhor fitness final: 2135.52
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - ROSENBROCK
# ============================================================
# Melhor fitness geral:               1539.32
# Pior fitness (máximo observado):    5637.07
# Fitness médio:                      3378.84
# Desvio padrão:                      1061.19
# Mediana:                            3091.47
