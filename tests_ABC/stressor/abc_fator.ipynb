# %%
import math
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# # functions

# %%
def sphere(x):
    """Mínimo global: f(0, ..., 0) = 0"""
    return sum(xi**2 for xi in x)

def rastrigin(x):
    """Mínimo global: f(0, ..., 0) = 0"""
    n = len(x)
    return 10 * n + sum(xi**2 - 10 * np.cos(2 * np.pi * xi) for xi in x)

def rosenbrock(x):
    """Mínimo global: f(1, ..., 1) = 0"""
    return sum(100 * (x[i+1] - x[i]**2)**2 + (x[i] - 1)**2 for i in range(len(x)-1))

# %% [markdown]
# # parameters

# %%
DIMENSIONS = 30              # Número de dimensões do espaço de busca (DIM)
GLOBAL_BEST = 0              # Melhor valor global conhecido
CS = 100                      # Tamanho da Colônia (Colony Size)
CICLOS = 100                 # Número de iterações/ciclos do algoritmo
RANDOM_SEED = 42             # Semente aleatória para reprodutibilidade
EXECUTIONS = 30              # Número de execuções para cada função
CONVERGENCE = 1e-5           # Critério de convergência

# Cálculo dinâmico do fator de abandono conforme solicitado: ((CS / 2) * DIM) / 2 e ((CS / 2) * DIM) / 4
FATOR_ABANDONO = ((CS / 2) * DIMENSIONS)

SELECTION_MODE = 'roulette' # Escolha entre 'roulette' (roleta) ou 'tournament' (torneio)
TOURNAMENT_SIZE = 3          # Quantidade de abelhas no torneio

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # bees

# %%
def get_fitness(value):
    """Calcula a aptidão: menores valores de custo resultam em maior fitness."""
    if value >= 0:
        return 1 / (value + 1)
    else:
        return 1 + abs(value)

def selection(bees, mode='roulette'):
    """Seleção de abelhas operárias pelas observadoras com base em Roleta ou Torneio."""
    if mode == 'roulette':
        fitnesses = [b.fitness for b in bees]
        total_fitness = sum(fitnesses)
        probs = [f / total_fitness for f in fitnesses]
        return np.random.choice(bees, p=probs)
    elif mode == 'tournament':
        competitors = random.sample(bees, TOURNAMENT_SIZE)
        return max(competitors, key=lambda b: b.fitness)

class Bee():
    def __init__(self, b_lo, b_hi, actual_function):
        self.b_lo = b_lo
        self.b_hi = b_hi
        self.actual_function = actual_function
        self.pos = np.random.uniform(b_lo, b_hi, DIMENSIONS)
        self.value = self.actual_function(self.pos)
        self.fitness = get_fitness(self.value)
        self.trials = 0

    def explore(self, target_pos, neighbor_pos):
        """
        Gera uma nova posição variando os dados da equação clássica do ABC:
        v_ij = x_ij + phi * (x_ij - x_kj)
        """
        new_pos = target_pos.copy()
        
        j = random.randint(0, DIMENSIONS - 1)
        phi = random.uniform(-1, 1)
        
        new_pos[j] = target_pos[j] + phi * (target_pos[j] - neighbor_pos[j])
        new_pos[j] = max(self.b_lo, min(self.b_hi, new_pos[j]))
        
        new_value = self.actual_function(new_pos)
        new_fitness = get_fitness(new_value)
        
        if new_fitness > self.fitness:
            self.pos = new_pos
            self.value = new_value
            self.fitness = new_fitness
            self.trials = 0
        else:
            self.trials += 1

    def reset(self):
        """Fase da Escoteira: Reinicializa se exceder o FATOR_ABANDONO."""
        self.pos = np.random.uniform(self.b_lo, self.b_hi, DIMENSIONS)
        self.value = self.actual_function(self.pos)
        self.fitness = get_fitness(self.value)
        self.trials = 0

# %% [markdown]
# # problem

# %%
def artificial_bee_colony(selection_mode='roulette'):
    resultados_finais = {}

    for actual_function in [sphere, rastrigin, rosenbrock]:
        print(f"\n{'='*70}")
        print(f"INICIANDO TESTES PARA A FUNÇÃO: {actual_function.__name__.upper()}")
        print(f"{'='*70}\n")
        
        # Limites do espaço de busca
        if actual_function.__name__ == 'rastrigin':
            b_lo, b_hi = -5.12, 5.12
        elif actual_function.__name__ == 'rosenbrock':
            b_lo, b_hi = -30.0, 30.0
        else:
            b_lo, b_hi = -100.0, 100.0

        curvas_desta_funcao = []
        melhor_fitness_por_exec = [] # Armazena o melhor resultado de cada uma das 30 rodadas

        for execution in range(EXECUTIONS):
            convergence_curve = []
            
            seed_atual = RANDOM_SEED + execution
            random.seed(seed_atual)
            np.random.seed(seed_atual)
            
            # Divisão da colônia (Metade operárias, metade observadoras)
            num_employees = CS // 2
            employees = [Bee(b_lo, b_hi, actual_function) for _ in range(num_employees)]
            onlookers = [Bee(b_lo, b_hi, actual_function) for _ in range(CS - num_employees)]
            
            best_value = math.inf
            
            curr_iter = 0
            while curr_iter < CICLOS:
                
                # 1. Fase das Abelhas Operárias
                for i, bee in enumerate(employees):
                    k = random.choice([x for x in range(num_employees) if x != i])
                    neighbor_pos = employees[k].pos
                    bee.explore(target_pos=bee.pos, neighbor_pos=neighbor_pos)
                
                # 2. Fase das Abelhas Observadoras
                for bee in onlookers:
                    chosen_employee = selection(employees, mode=selection_mode)
                    k = random.randint(0, num_employees - 1)
                    neighbor_pos = employees[k].pos
                    bee.explore(target_pos=chosen_employee.pos, neighbor_pos=neighbor_pos)
                
                # 3. Fase das Escoteiras (Verifica o limite de abandono)
                for bee in employees + onlookers:
                    if bee.trials >= FATOR_ABANDONO:
                        bee.reset()
                        
                # 4. Atualiza a melhor solução global
                current_best = min(employees + onlookers, key=lambda b: b.value).value
                if current_best < best_value:
                    best_value = current_best
                    
                convergence_curve.append(best_value)
                
                # Critério de Parada Antecipada por Convergência
                if abs(best_value - GLOBAL_BEST) < CONVERGENCE:
                    resto_iters = CICLOS - curr_iter - 1
                    convergence_curve.extend([best_value] * resto_iters)
                    break
                    
                curr_iter += 1

            # Salvar resultados da execução
            curvas_desta_funcao.append(convergence_curve)
            melhor_fitness_por_exec.append(best_value)
            
            print(f"Execução {execution+1:02d}/{EXECUTIONS} (seed={seed_atual:3d}) | Melhor fitness final: {best_value:.2f}")
        
        # Calcular a média das curvas para o gráfico
        media_curvas = np.mean(curvas_desta_funcao, axis=0)
        resultados_finais[actual_function.__name__] = media_curvas
        
        # Impressão do Bloco Estatístico (Cópia exata do padrão do AG)
        print(f"\n{'='*60}")
        print(f"RESULTADOS FINAIS APÓS {EXECUTIONS} EXECUÇÕES - {actual_function.__name__.upper()}")
        print(f"{'='*60}")
        print(f"Melhor fitness geral:               {np.min(melhor_fitness_por_exec):.2f}")
        print(f"Pior fitness (máximo observado):    {np.max(melhor_fitness_por_exec):.2f}")
        print(f"Fitness médio:                      {np.mean(melhor_fitness_por_exec):.2f}")
        print(f"Desvio padrão:                      {np.std(melhor_fitness_por_exec):.2f}")
        print(f"Mediana:                            {np.median(melhor_fitness_por_exec):.2f}")

    # Geração dos gráficos ao final de todos os testes
    plt.figure(figsize=(10, 6))
    for nome_funcao, media_curva in resultados_finais.items():
        curva_segura = [max(val, 1e-10) for val in media_curva]
        plt.plot(curva_segura, label=nome_funcao.capitalize(), linewidth=2)

    plt.title(f"Curva de Convergência Média ABC ({EXECUTIONS} Execuções - {DIMENSIONS}D)")
    plt.xlabel("Iterações")
    plt.ylabel("Melhor Custo (Z) - Escala Log")
    plt.yscale("log")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
#rodar
artificial_bee_colony(selection_mode=SELECTION_MODE)
# Out:
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: SPHERE
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 15090.90
# Execução 02/30 (seed= 43) | Melhor fitness final: 17753.91
# Execução 03/30 (seed= 44) | Melhor fitness final: 9549.85
# Execução 04/30 (seed= 45) | Melhor fitness final: 15364.53
# Execução 05/30 (seed= 46) | Melhor fitness final: 14451.33
# Execução 06/30 (seed= 47) | Melhor fitness final: 16562.33
# Execução 07/30 (seed= 48) | Melhor fitness final: 14283.33
# Execução 08/30 (seed= 49) | Melhor fitness final: 10089.33
# Execução 09/30 (seed= 50) | Melhor fitness final: 19790.18
# Execução 10/30 (seed= 51) | Melhor fitness final: 22192.28
# Execução 11/30 (seed= 52) | Melhor fitness final: 14726.19
# Execução 12/30 (seed= 53) | Melhor fitness final: 17315.15
# Execução 13/30 (seed= 54) | Melhor fitness final: 11677.58
# Execução 14/30 (seed= 55) | Melhor fitness final: 12194.50
# Execução 15/30 (seed= 56) | Melhor fitness final: 17070.65
# Execução 16/30 (seed= 57) | Melhor fitness final: 17709.97
# Execução 17/30 (seed= 58) | Melhor fitness final: 17537.00
# Execução 18/30 (seed= 59) | Melhor fitness final: 14297.24
# Execução 19/30 (seed= 60) | Melhor fitness final: 17770.70
# Execução 20/30 (seed= 61) | Melhor fitness final: 11906.73
# Execução 21/30 (seed= 62) | Melhor fitness final: 16838.72
# Execução 22/30 (seed= 63) | Melhor fitness final: 15736.27
# Execução 23/30 (seed= 64) | Melhor fitness final: 16360.03
# Execução 24/30 (seed= 65) | Melhor fitness final: 16704.91
# Execução 25/30 (seed= 66) | Melhor fitness final: 19556.75
# Execução 26/30 (seed= 67) | Melhor fitness final: 16541.48
# Execução 27/30 (seed= 68) | Melhor fitness final: 19756.73
# Execução 28/30 (seed= 69) | Melhor fitness final: 18280.19
# Execução 29/30 (seed= 70) | Melhor fitness final: 10460.25
# Execução 30/30 (seed= 71) | Melhor fitness final: 11751.13
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - SPHERE
# ============================================================
# Melhor fitness geral:               9549.85
# Pior fitness (máximo observado):    22192.28
# Fitness médio:                      15644.00
# Desvio padrão:                      3074.37
# Mediana:                            16450.76
#
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: RASTRIGIN
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 191.74
# Execução 02/30 (seed= 43) | Melhor fitness final: 206.46
# Execução 03/30 (seed= 44) | Melhor fitness final: 176.50
# Execução 04/30 (seed= 45) | Melhor fitness final: 182.96
# Execução 05/30 (seed= 46) | Melhor fitness final: 194.32
# Execução 06/30 (seed= 47) | Melhor fitness final: 189.64
# Execução 07/30 (seed= 48) | Melhor fitness final: 189.42
# Execução 08/30 (seed= 49) | Melhor fitness final: 175.27
# Execução 09/30 (seed= 50) | Melhor fitness final: 199.20
# Execução 10/30 (seed= 51) | Melhor fitness final: 222.53
# Execução 11/30 (seed= 52) | Melhor fitness final: 206.02
# Execução 12/30 (seed= 53) | Melhor fitness final: 151.28
# Execução 13/30 (seed= 54) | Melhor fitness final: 177.24
# Execução 14/30 (seed= 55) | Melhor fitness final: 183.36
# Execução 15/30 (seed= 56) | Melhor fitness final: 196.11
# Execução 16/30 (seed= 57) | Melhor fitness final: 173.20
# Execução 17/30 (seed= 58) | Melhor fitness final: 204.29
# Execução 18/30 (seed= 59) | Melhor fitness final: 175.31
# Execução 19/30 (seed= 60) | Melhor fitness final: 184.16
# Execução 20/30 (seed= 61) | Melhor fitness final: 155.75
# Execução 21/30 (seed= 62) | Melhor fitness final: 155.32
# Execução 22/30 (seed= 63) | Melhor fitness final: 200.90
# Execução 23/30 (seed= 64) | Melhor fitness final: 181.60
# Execução 24/30 (seed= 65) | Melhor fitness final: 190.40
# Execução 25/30 (seed= 66) | Melhor fitness final: 218.91
# Execução 26/30 (seed= 67) | Melhor fitness final: 207.07
# Execução 27/30 (seed= 68) | Melhor fitness final: 173.33
# Execução 28/30 (seed= 69) | Melhor fitness final: 204.60
# Execução 29/30 (seed= 70) | Melhor fitness final: 158.09
# Execução 30/30 (seed= 71) | Melhor fitness final: 183.59
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - RASTRIGIN
# ============================================================
# Melhor fitness geral:               151.28
# Pior fitness (máximo observado):    222.53
# Fitness médio:                      186.95
# Desvio padrão:                      17.88
# Mediana:                            186.79
#
# ======================================================================
# INICIANDO TESTES PARA A FUNÇÃO: ROSENBROCK
# ======================================================================
#
# Execução 01/30 (seed= 42) | Melhor fitness final: 19721533.85
# Execução 02/30 (seed= 43) | Melhor fitness final: 31393952.29
# Execução 03/30 (seed= 44) | Melhor fitness final: 9080956.95
# Execução 04/30 (seed= 45) | Melhor fitness final: 24123304.22
# Execução 05/30 (seed= 46) | Melhor fitness final: 27548303.03
# Execução 06/30 (seed= 47) | Melhor fitness final: 35336409.33
# Execução 07/30 (seed= 48) | Melhor fitness final: 15340244.69
# Execução 08/30 (seed= 49) | Melhor fitness final: 9428268.66
# Execução 09/30 (seed= 50) | Melhor fitness final: 40801555.28
# Execução 10/30 (seed= 51) | Melhor fitness final: 51286144.53
# Execução 11/30 (seed= 52) | Melhor fitness final: 12194449.83
# Execução 12/30 (seed= 53) | Melhor fitness final: 16638285.92
# Execução 13/30 (seed= 54) | Melhor fitness final: 17951443.90
# Execução 14/30 (seed= 55) | Melhor fitness final: 8872302.40
# Execução 15/30 (seed= 56) | Melhor fitness final: 31386279.14
# Execução 16/30 (seed= 57) | Melhor fitness final: 19911003.91
# Execução 17/30 (seed= 58) | Melhor fitness final: 25068483.25
# Execução 18/30 (seed= 59) | Melhor fitness final: 16104993.73
# Execução 19/30 (seed= 60) | Melhor fitness final: 35322260.44
# Execução 20/30 (seed= 61) | Melhor fitness final: 7588771.29
# Execução 21/30 (seed= 62) | Melhor fitness final: 22576038.85
# Execução 22/30 (seed= 63) | Melhor fitness final: 21424450.29
# Execução 23/30 (seed= 64) | Melhor fitness final: 23184806.00
# Execução 24/30 (seed= 65) | Melhor fitness final: 38389141.72
# Execução 25/30 (seed= 66) | Melhor fitness final: 32912327.38
# Execução 26/30 (seed= 67) | Melhor fitness final: 23721369.02
# Execução 27/30 (seed= 68) | Melhor fitness final: 33669182.20
# Execução 28/30 (seed= 69) | Melhor fitness final: 29329768.85
# Execução 29/30 (seed= 70) | Melhor fitness final: 9777999.72
# Execução 30/30 (seed= 71) | Melhor fitness final: 10704606.00
#
# ============================================================
# RESULTADOS FINAIS APÓS 30 EXECUÇÕES - ROSENBROCK
# ============================================================
# Melhor fitness geral:               7588771.29
# Pior fitness (máximo observado):    51286144.53
# Fitness médio:                      23359621.22
# Desvio padrão:                      10842210.87
# Mediana:                            22880422.43
