# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
# parametros do AG
n_pop = 50
quantidade_genes = 50
n_geracoes = 150
pop = []
nova_pop = []
n_cortes = 1
taxa_crossover = 0.8
taxa_mutacao = 0.05
selecao='torneio'

# Random seed
random_seed = 42

# Parametros da sphere
n_dimensoes = quantidade_genes
var_min = -100
var_max = 100

#elitismo
n_elitismo = 2

# %% [markdown]
# ## Gerar População

# %%
# Configurar seed para reprodutibilidade
random.seed(random_seed)
np.random.seed(random_seed)

pop.clear()
#Loop para criar cada indivíduo da população:
for i in range(n_pop):
    cromossomo = [random.uniform(var_min, var_max) for _ in range(n_dimensoes)]
    pop.append(cromossomo)
    #print(f"cromossomo {i+1} gerado: {cromossomo}")
    #print("\n")

# %%
#pop

# %% [markdown]
# ## Função Sphere

# %%
def sphere(x):
    """
    Sphere Function
    Mínimo global: f(0, ..., 0) = 0
    """
    return sum(xi**2 for xi in x)

# %% [markdown]
# ## Avaliar cada individuo

# %%
pop_aval= []
pop_aval.clear()
for cromossomo in pop:
    nota_aval = sphere(cromossomo)
    pop_aval.append((cromossomo, nota_aval))

#pop_aval

# %% [markdown]
# ## Selecionar os individuos mais aptos

# %%
def calcular_fitness(pop_avaliada):
    """
    Recebe: lista de tuplas (cromossomo, valor_sphere)
    Retorna: lista de pesos de fitness
    """
    return [1 / (1 + individuo[1]) for individuo in pop_avaliada]

#def mostrar_probabilidade(pop_avaliada):
#    """
#    Mostra cada cromossomo com sua avaliação e probabilidade relativa
#    """
#    fitness = calcular_fitness(pop_avaliada)
#    total = sum(fitness)
#    probabilidades = [f/total for f in fitness]
#
#    for i, (crom, fitness) in enumerate(pop_avaliada):
#        print(f"Cromossomo {i+1}: avaliação={fitness:.2f}, probabilidade={probabilidades[i]*100:.2f}%")

def selecao_proporcional(pop_avaliada, n_pop_selec):
    """
    Recebe: população avaliada e quantidade a selecionar
    Retorna: apenas os cromossomos selecionados (sem o valor da sphere)
    """
    fitness = calcular_fitness(pop_avaliada)

    grupo_survivors = random.choices(pop_avaliada, weights=fitness, k=n_pop_selec)
    
    # retorna só os cromossomos, sem o valor da sphere
    return [individuo[0] for individuo in grupo_survivors]

# %%
#mostrar_probabilidade(pop_aval)
#len(p1_survivors)

# %%
def selecao_torneio(pop_avaliada, n_pop_selec):
    """
    Recebe: população avaliada [(cromossomo, avaliação), ...]
    Retorna: lista de cromossomos selecionados via torneio
    """
    grupo_survivors = []
    for rodada in range(n_pop_selec):
        # sorteiar 2 competidores
        c1, c2 = random.choices(pop_avaliada, k=2)

        # mostrar os competidores
        #print(f"Torneio {rodada+1}:")
        #print(f"  Competidor 1 -> avaliação={c1[1]:.2f}")
        #print(f"  Competidor 2 -> avaliação={c2[1]:.2f}")

        # comparar avaliações (menor é melhor)
        if c1[1] < c2[1]:
            survivor = c1
        else:
            survivor = c2

        #print(f"  Vencedor -> avaliação={survivor[1]:.2f}\n")

        grupo_survivors.append(survivor[0])  # pega só o cromossomo

    return grupo_survivors

# %%
def selecionar_pais(selecao, pop_avaliada, n_pop_selec):
    """
    Recebe: lista de tuplas (cromossomo, valor_sphere)          
    :param selecao: 
    :param pop_avaliada: 
    :param n_pop_selec: 
    :return: lista de p1 e p2 selecionados
    """
    if selecao.lower().strip() == 'torneio':
        p1_survivors = selecao_torneio(pop_avaliada, n_pop_selec)
        p2_survivors= selecao_torneio(pop_avaliada, n_pop_selec)
    else:
        p1_survivors = selecao_proporcional(pop_avaliada, n_pop_selec)
        p2_survivors = selecao_proporcional(pop_avaliada, n_pop_selec)
    return p1_survivors, p2_survivors

# %%
def crossover_1pt(p1, p2, taxa_crossover, quantidade_genes):
    """
    Recebe: dois pais (Selecionados/sobreviventes), taxa de crossover e a quantidade de genes
    Retorna: dois filhos
    """
    # verifica se há cruzamento
    if random.random() < taxa_crossover:
        ponto_corte = random.randint(1, quantidade_genes - 1)
        
        # troca as partes após o ponto de corte
        filho1 = p1[:ponto_corte] + p2[ponto_corte:]
        filho2 = p2[:ponto_corte] + p1[ponto_corte:]
        #print(f"crossover: {filho1} + {filho2}\n")
    else:
        # sem cruzamento, filhos são cópias dos pais
        filho1 = p1[:]
        filho2 = p2[:]
        #print(f"sem crossover: {filho1} + {filho2}\n")
    
    return filho1, filho2

# %%
def mutacao(cromossomo, taxa_mutacao, quantidade_genes, var_min, var_max):
    """
    Recebe: cromossomo, quantidade de genes, taxa de mutação e limites
    Retorna: cromossomo (com possíveis mutações)
    """
    cromossomo_mutado = cromossomo[:]  # copia para não alterar o original
    
    for i in range(quantidade_genes):
        if random.random() < taxa_mutacao:
            cromossomo_mutado[i] = random.uniform(var_min, var_max)
            #print(f"mutacao no {i+1}: {cromossomo} ---> {cromossomo_mutado}\n")
    
    return cromossomo_mutado

# %%
def gerar_nova_pop(p1_survivors, p2_survivors, quantidade_genes,n_pop,
                          taxa_crossover, taxa_mutacao, 
                          var_min, var_max, nova_pop):
    """
    Recebe: listas de pais selecionados, quantidade de genes, a lista de nova populção, taxas e limites
    Retorna: nova população após crossover e mutação
    """
    
    # percorre os pais em pares
    for i in range(0, n_pop):
        
        p1 = random.choice(p1_survivors)
        p2 = random.choice(p2_survivors)
        
        # crossover
        filho1, filho2 = crossover_1pt(p1, p2, taxa_crossover, quantidade_genes)
        
        # mutação em cada filho
        filho1 = mutacao(filho1, taxa_mutacao, quantidade_genes, var_min, var_max)
        filho2 = mutacao(filho2, taxa_mutacao, quantidade_genes, var_min, var_max)
        
        nova_pop.append(filho1)
        nova_pop.append(filho2)
        
    return nova_pop

# %% [markdown]
# ## Loop exec - Critério de parada - GERAÇÕES

# %%
historico_melhor = []
historico_notas = []  # para visualizar a evolução

for geracao in range(n_geracoes):

    # 1. Avaliar população atual
    pop_aval = [(crom, sphere(crom)) for crom in pop]

    notas_avaliacao = [aval for _, aval in pop_aval]
    historico_notas.append(notas_avaliacao)

    # 2. Elitismo: preservar os n_elitismo melhores
    pop_aval_ord = sorted(pop_aval, key=lambda x: x[1])
    elites = [ind[0] for ind in pop_aval_ord[:n_elitismo]]

    # 3. Selecionar pais
    p1_survivors, p2_survivors = selecionar_pais(selecao, pop_aval, n_pop)

    # 4. Gerar (n_pop - n_elitismo) filhos para abrir espaço para os elites
    nova_pop.clear()
    gerar_nova_pop(p1_survivors, p2_survivors, quantidade_genes, n_pop - n_elitismo,
                   taxa_crossover, taxa_mutacao, var_min, var_max, nova_pop)

    # 5. Avaliar filhos e ordenar
    filhos_aval = [(crom, sphere(crom)) for crom in nova_pop]
    filhos_aval.sort(key=lambda x: x[1])
    melhores_filhos = [ind[0] for ind in filhos_aval[:n_pop - n_elitismo]]

    # 6. Nova população = elites + melhores filhos
    pop = elites + melhores_filhos

    # 7. Registrar o melhor fitness da geração (considerando elites também)
    melhor_fitness = min(sphere(ind) for ind in pop)
    historico_melhor.append(melhor_fitness)
    print(f"Geração {geracao+1:02d} | Melhor fitness: {melhor_fitness:.2f}")

# Resultado final
print(f"\n{'='*40}")
print(f"RESULTADO FINAL após {n_geracoes} gerações:")
print(f"Melhor fitness encontrado: {min(historico_melhor):.2f}")
print(f"Geração onde ocorreu: {historico_melhor.index(min(historico_melhor)) + 1}")
# Out:
# Geração 01 | Melhor fitness: 115037.96
# Geração 02 | Melhor fitness: 112925.04
# Geração 03 | Melhor fitness: 104511.86
# Geração 04 | Melhor fitness: 101954.26
# Geração 05 | Melhor fitness: 90262.53
# Geração 06 | Melhor fitness: 85293.58
# Geração 07 | Melhor fitness: 83352.54
# Geração 08 | Melhor fitness: 75982.39
# Geração 09 | Melhor fitness: 69713.29
# Geração 10 | Melhor fitness: 64869.28
# Geração 11 | Melhor fitness: 54401.39
# Geração 12 | Melhor fitness: 54401.39
# Geração 13 | Melhor fitness: 53605.53
# Geração 14 | Melhor fitness: 53605.53
# Geração 15 | Melhor fitness: 49572.39
# Geração 16 | Melhor fitness: 47172.77
# Geração 17 | Melhor fitness: 46128.41
# Geração 18 | Melhor fitness: 45416.85
# Geração 19 | Melhor fitness: 37513.43
# Geração 20 | Melhor fitness: 37513.43
# Geração 21 | Melhor fitness: 34010.92
# Geração 22 | Melhor fitness: 34010.92
# Geração 23 | Melhor fitness: 32200.61
# Geração 24 | Melhor fitness: 32071.17
# Geração 25 | Melhor fitness: 32071.17
# Geração 26 | Melhor fitness: 28385.05
# Geração 27 | Melhor fitness: 28385.05
# Geração 28 | Melhor fitness: 28385.05
# Geração 29 | Melhor fitness: 25201.60
# Geração 30 | Melhor fitness: 25201.60
# Geração 31 | Melhor fitness: 24892.24
# Geração 32 | Melhor fitness: 22846.83
# Geração 33 | Melhor fitness: 22846.83
# Geração 34 | Melhor fitness: 22680.41
# Geração 35 | Melhor fitness: 21361.09
# Geração 36 | Melhor fitness: 19992.28
# Geração 37 | Melhor fitness: 19788.12
# Geração 38 | Melhor fitness: 17353.60
# Geração 39 | Melhor fitness: 17353.60
# Geração 40 | Melhor fitness: 16360.09
# Geração 41 | Melhor fitness: 16360.09
# Geração 42 | Melhor fitness: 15277.59
# Geração 43 | Melhor fitness: 15277.59
# Geração 44 | Melhor fitness: 15277.59
# Geração 45 | Melhor fitness: 15181.70
# Geração 46 | Melhor fitness: 14875.10
# Geração 47 | Melhor fitness: 14296.26
# Geração 48 | Melhor fitness: 14078.06
# Geração 49 | Melhor fitness: 14078.06
# Geração 50 | Melhor fitness: 13778.33
# Geração 51 | Melhor fitness: 13172.74
# Geração 52 | Melhor fitness: 13172.74
# Geração 53 | Melhor fitness: 12659.11
# Geração 54 | Melhor fitness: 11352.89
# Geração 55 | Melhor fitness: 11352.89
# Geração 56 | Melhor fitness: 11352.89
# Geração 57 | Melhor fitness: 11352.89
# Geração 58 | Melhor fitness: 11284.09
# Geração 59 | Melhor fitness: 11284.09
# Geração 60 | Melhor fitness: 11284.09
# Geração 61 | Melhor fitness: 11284.09
# Geração 62 | Melhor fitness: 10967.58
# Geração 63 | Melhor fitness: 10580.75
# Geração 64 | Melhor fitness: 10580.75
# Geração 65 | Melhor fitness: 10488.39
# Geração 66 | Melhor fitness: 10488.39
# Geração 67 | Melhor fitness: 10488.39
# Geração 68 | Melhor fitness: 10271.25
# Geração 69 | Melhor fitness: 10271.25
# Geração 70 | Melhor fitness: 9547.07
# Geração 71 | Melhor fitness: 9547.07
# Geração 72 | Melhor fitness: 9235.15
# Geração 73 | Melhor fitness: 9235.15
# Geração 74 | Melhor fitness: 9235.15
# Geração 75 | Melhor fitness: 9235.15
# Geração 76 | Melhor fitness: 8756.92
# Geração 77 | Melhor fitness: 8552.54
# Geração 78 | Melhor fitness: 8552.54
# Geração 79 | Melhor fitness: 8309.56
# Geração 80 | Melhor fitness: 8309.56
# Geração 81 | Melhor fitness: 8290.40
# Geração 82 | Melhor fitness: 8035.35
# Geração 83 | Melhor fitness: 8035.35
# Geração 84 | Melhor fitness: 8035.35
# Geração 85 | Melhor fitness: 8035.35
# Geração 86 | Melhor fitness: 8035.35
# Geração 87 | Melhor fitness: 8035.35
# Geração 88 | Melhor fitness: 8035.35
# Geração 89 | Melhor fitness: 8035.35
# Geração 90 | Melhor fitness: 8035.35
# Geração 91 | Melhor fitness: 7602.02
# Geração 92 | Melhor fitness: 7602.02
# Geração 93 | Melhor fitness: 7602.02
# Geração 94 | Melhor fitness: 7602.02
# Geração 95 | Melhor fitness: 7602.02
# Geração 96 | Melhor fitness: 7602.02
# Geração 97 | Melhor fitness: 7602.02
# Geração 98 | Melhor fitness: 7602.02
# Geração 99 | Melhor fitness: 7602.02
# Geração 100 | Melhor fitness: 7602.02
# Geração 101 | Melhor fitness: 7602.02
# Geração 102 | Melhor fitness: 7592.74
# Geração 103 | Melhor fitness: 7592.74
# Geração 104 | Melhor fitness: 7592.74
# Geração 105 | Melhor fitness: 7472.06
# Geração 106 | Melhor fitness: 7472.06
# Geração 107 | Melhor fitness: 7256.75
# Geração 108 | Melhor fitness: 6977.32
# Geração 109 | Melhor fitness: 6977.32
# Geração 110 | Melhor fitness: 6977.32
# Geração 111 | Melhor fitness: 6977.32
# Geração 112 | Melhor fitness: 6861.75
# Geração 113 | Melhor fitness: 6861.75
# Geração 114 | Melhor fitness: 6861.75
# Geração 115 | Melhor fitness: 6861.75
# Geração 116 | Melhor fitness: 6861.75
# Geração 117 | Melhor fitness: 6748.18
# Geração 118 | Melhor fitness: 6748.18
# Geração 119 | Melhor fitness: 6748.18
# Geração 120 | Melhor fitness: 6323.26
# Geração 121 | Melhor fitness: 5782.37
# Geração 122 | Melhor fitness: 5782.37
# Geração 123 | Melhor fitness: 5782.37
# Geração 124 | Melhor fitness: 5782.37
# Geração 125 | Melhor fitness: 5762.87
# Geração 126 | Melhor fitness: 5662.62
# Geração 127 | Melhor fitness: 5662.62
# Geração 128 | Melhor fitness: 5662.62
# Geração 129 | Melhor fitness: 5662.62
# Geração 130 | Melhor fitness: 5662.62
# Geração 131 | Melhor fitness: 5662.62
# Geração 132 | Melhor fitness: 5662.62
# Geração 133 | Melhor fitness: 5662.62
# Geração 134 | Melhor fitness: 5662.62
# Geração 135 | Melhor fitness: 5662.62
# Geração 136 | Melhor fitness: 5662.62
# Geração 137 | Melhor fitness: 5426.05
# Geração 138 | Melhor fitness: 5426.05
# Geração 139 | Melhor fitness: 5426.05
# Geração 140 | Melhor fitness: 5426.05
# Geração 141 | Melhor fitness: 5426.05
# Geração 142 | Melhor fitness: 5426.05
# Geração 143 | Melhor fitness: 5426.05
# Geração 144 | Melhor fitness: 5168.41
# Geração 145 | Melhor fitness: 5168.41
# Geração 146 | Melhor fitness: 5168.41
# Geração 147 | Melhor fitness: 5168.41
# Geração 148 | Melhor fitness: 5168.41
# Geração 149 | Melhor fitness: 5104.36
# Geração 150 | Melhor fitness: 5104.36
#
# ========================================
# RESULTADO FINAL após 150 gerações:
# Melhor fitness encontrado: 5104.36
# Geração onde ocorreu: 149

# %%
p1_survivors, p2_survivors = selecionar_pais(selecao, pop_aval, n_pop)

# %% [markdown]
# ## Gráficos

# %%
# Gráfico de convergência
media_por_geracao = [np.mean(gen) for gen in historico_notas]
plt.plot(range(1, n_geracoes+1), historico_melhor, label="Melhor fitness")
plt.plot(range(1, n_geracoes+1), media_por_geracao, label="Média fitness", linestyle="--")
plt.xlabel("Geração")
plt.ylabel("Fitness")
plt.legend()
plt.show()

# Boxplot
plt.boxplot(historico_notas, positions=range(1, n_geracoes+1), showmeans=True)
plt.xlabel("Geração")
plt.ylabel("Fitness")
plt.show()
